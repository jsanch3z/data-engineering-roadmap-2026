# %% [markdown]
# 🟦 FASE 1 — Capa RAW

# %%
import pandas as pd
df = pd.read_parquet('yellow_tripdata_2024-01.parquet')
df.to_csv('yellow_tripdata_2024-01.csv', index=False)

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi -c "SELECT 1;"
# Out:
#  ?column?
# ----------
#         1
# (1 row)

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# CREATE SCHEMA IF NOT EXISTS raw;
# SQL
# Out:
# CREATE SCHEMA

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# DROP TABLE IF EXISTS raw.yellow_taxi_raw;
#
# CREATE TABLE raw.yellow_taxi_raw (
#     vendor_id TEXT,
#     pickup_datetime TEXT,
#     dropoff_datetime TEXT,
#     passenger_count TEXT,
#     trip_distance TEXT,
#     ratecode_id TEXT,
#     store_and_fwd_flag TEXT,
#     pulocation_id TEXT,
#     dolocation_id TEXT,
#     payment_type TEXT,
#     fare_amount TEXT,
#     extra TEXT,
#     mta_tax TEXT,
#     tip_amount TEXT,
#     tolls_amount TEXT,
#     improvement_surcharge TEXT,
#     total_amount TEXT,
#     congestion_surcharge TEXT,
#     airport_fee TEXT
# );
# SQL
# Out:
# NOTICE:  table "yellow_taxi_raw" does not exist, skipping
# DROP TABLE
# CREATE TABLE

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# \copy raw.yellow_taxi_raw FROM 'yellow_tripdata_2024-01.csv' CSV HEADER;
# SQL
# Out:
# COPY 2964624

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# SELECT COUNT(*) FROM raw.yellow_taxi_raw;
# SQL
# Out:
#   count
# ---------
#  2964624
# (1 row)

# %% [markdown]
# ## 🟩 FASE 2 — Modelo Relacional (CURATED)

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# CREATE SCHEMA IF NOT EXISTS curated;
# SQL
# Out:
# CREATE SCHEMA

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# DROP TABLE IF EXISTS curated.trip CASCADE;
#
# CREATE TABLE curated.trip (
#     trip_id BIGSERIAL PRIMARY KEY,
#     vendor_id INTEGER,
#     pickup_datetime TIMESTAMP,
#     dropoff_datetime TIMESTAMP,
#     passenger_count INTEGER,
#     trip_distance NUMERIC,
#     fare_amount NUMERIC,
#     tip_amount NUMERIC,
#     total_amount NUMERIC,
#     pulocation_id INTEGER,
#     dolocation_id INTEGER
# );
# SQL
# Out:
# DROP TABLE
# CREATE TABLE

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# INSERT INTO curated.trip (
#     vendor_id,
#     pickup_datetime,
#     dropoff_datetime,
#     passenger_count,
#     trip_distance,
#     fare_amount,
#     tip_amount,
#     total_amount,
#     pulocation_id,
#     dolocation_id
# )
# SELECT
#     vendor_id::INTEGER,
#     pickup_datetime::TIMESTAMP,
#     dropoff_datetime::TIMESTAMP,
#     passenger_count::INTEGER,
#     trip_distance::NUMERIC,
#     fare_amount::NUMERIC,
#     tip_amount::NUMERIC,
#     total_amount::NUMERIC,
#     pulocation_id::INTEGER,
#     dolocation_id::INTEGER
# FROM raw.yellow_taxi_raw;
# SQL
# Out:
# ERROR:  invalid input syntax for type integer: "1.0"

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# INSERT INTO curated.trip (
#     vendor_id,
#     pickup_datetime,
#     dropoff_datetime,
#     passenger_count,
#     trip_distance,
#     fare_amount,
#     tip_amount,
#     total_amount,
#     pulocation_id,
#     dolocation_id
# )
# SELECT
#     vendor_id::INTEGER,
#     pickup_datetime::TIMESTAMP,
#     dropoff_datetime::TIMESTAMP,
#     passenger_count::NUMERIC::INTEGER,
#     trip_distance::NUMERIC,
#     fare_amount::NUMERIC,
#     tip_amount::NUMERIC,
#     total_amount::NUMERIC,
#     pulocation_id::INTEGER,
#     dolocation_id::INTEGER
# FROM raw.yellow_taxi_raw;
# SQL
# Out:
# INSERT 0 2964624

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# SELECT COUNT(*) FROM curated.trip;
# SQL
# Out:
#   count
# ---------
#  2964624
# (1 row)

# %% [markdown]
# ## 🟨 FASE 3 ANALYTICS — EDA, Índices y Performance

# %%
# %load_ext sql
# %sql postgresql://root:root@localhost:5432/ny_taxi
# Out:
# Connecting to 'postgresql://root:***@localhost:5432/ny_taxi'

# %%
# %%sql
# SELECT
#     COUNT(*) AS total_trips,
#     MIN(pickup_datetime),
#     MAX(pickup_datetime)
# FROM curated.trip;
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 1 rows affected.
# +-------------+---------------------+---------------------+
# | total_trips |         min         |         max         |
# +-------------+---------------------+---------------------+
# |   2964624   | 2002-12-31 22:59:39 | 2024-02-01 00:01:15 |
# +-------------+---------------------+---------------------+

# %%
# %%sql
# SELECT
#     DATE(pickup_datetime) AS day,
#     SUM(total_amount) AS revenue
# FROM curated.trip
# GROUP BY day
# ORDER BY day;
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 35 rows affected.
# +------------+------------+
# |    day     |  revenue   |
# +------------+------------+
# | 2002-12-31 |    0.0     |
# | 2009-01-01 |   127.69   |
# | 2023-12-31 |   224.62   |
# | 2024-01-01 | 2442843.25 |
# | 2024-01-02 | 2282196.02 |
# | 2024-01-03 | 2357588.48 |
# | 2024-01-04 | 2800511.06 |
# | 2024-01-05 | 2728672.52 |
# | 2024-01-06 | 2436272.32 |
# | 2024-01-07 | 1898102.16 |
# +------------+------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# CREATE INDEX idx_trip_pickup_datetime
# ON curated.trip (pickup_datetime);
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# RuntimeError: (psycopg2.errors.DuplicateTable) relation "idx_trip_pickup_datetime" already exists
#
# [SQL: CREATE INDEX idx_trip_pickup_datetime
# ON curated.trip (pickup_datetime);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# EXPLAIN ANALYZE
# SELECT *
# FROM curated.trip
# WHERE pickup_datetime >= '2024-01-15';
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 5 rows affected.
# +-------------------------------------------------------------------------------------------------------------------+
# |                                                     QUERY PLAN                                                    |
# +-------------------------------------------------------------------------------------------------------------------+
# | Seq Scan on trip  (cost=0.00..94804.80 rows=1674845 width=63) (actual time=105.448..237.656 rows=1678072 loops=1) |
# |                   Filter: (pickup_datetime >= '2024-01-15 00:00:00'::timestamp without time zone)                 |
# |                                           Rows Removed by Filter: 1286552                                         |
# |                                              Planning Time: 0.217 ms                                              |
# |                                             Execution Time: 276.722 ms                                            |
# +-------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# # 🟧 FASE 4 — Preparación para OLAP

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# CREATE TABLE IF NOT EXISTS raw.taxi_zone_lookup (
#     location_id   INTEGER,
#     borough       TEXT,
#     zone_name     TEXT,
#     service_zone  TEXT
# );
# Out:
# bash: line 7: warning: here-document at line 1 delimited by end-of-file (wanted `SQL')
# CREATE TABLE

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# \copy raw.taxi_zone_lookup FROM 'taxi_zone_lookup.csv'CSV HEADER;
# SQL
# Out:
# COPY 265

# %%
# %%sql
# SELECT * FROM raw.taxi_zone_lookup
# LIMIT 10
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 10 rows affected.
# +-------------+---------------+-------------------------+--------------+
# | location_id |    borough    |        zone_name        | service_zone |
# +-------------+---------------+-------------------------+--------------+
# |      1      |      EWR      |      Newark Airport     |     EWR      |
# |      2      |     Queens    |       Jamaica Bay       |  Boro Zone   |
# |      3      |     Bronx     | Allerton/Pelham Gardens |  Boro Zone   |
# |      4      |   Manhattan   |      Alphabet City      | Yellow Zone  |
# |      5      | Staten Island |      Arden Heights      |  Boro Zone   |
# |      6      | Staten Island | Arrochar/Fort Wadsworth |  Boro Zone   |
# |      7      |     Queens    |         Astoria         |  Boro Zone   |
# |      8      |     Queens    |       Astoria Park      |  Boro Zone   |
# |      9      |     Queens    |        Auburndale       |  Boro Zone   |
# |      10     |     Queens    |       Baisley Park      |  Boro Zone   |
# +-------------+---------------+-------------------------+--------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# CREATE OR REPLACE VIEW curated.zone AS
# SELECT
#     location_id,
#     zone_name,
#     borough
# FROM raw.taxi_zone_lookup;
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * FROM curated.zone
# LIMIT 10
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 10 rows affected.
# +-------------+-------------------------+---------------+
# | location_id |        zone_name        |    borough    |
# +-------------+-------------------------+---------------+
# |      1      |      Newark Airport     |      EWR      |
# |      2      |       Jamaica Bay       |     Queens    |
# |      3      | Allerton/Pelham Gardens |     Bronx     |
# |      4      |      Alphabet City      |   Manhattan   |
# |      5      |      Arden Heights      | Staten Island |
# |      6      | Arrochar/Fort Wadsworth | Staten Island |
# |      7      |         Astoria         |     Queens    |
# |      8      |       Astoria Park      |     Queens    |
# |      9      |        Auburndale       |     Queens    |
# |      10     |       Baisley Park      |     Queens    |
# +-------------+-------------------------+---------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# CREATE OR REPLACE VIEW curated.vendor AS
# SELECT DISTINCT
#     vendor_id,
#     CASE vendor_id
#         WHEN 1 THEN 'Creative Mobile'
#         WHEN 2 THEN 'VeriFone'
#         ELSE 'Unknown'
#     END AS vendor_name
# FROM curated.trip;
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * FROM curated.vendor
# LIMIT 10
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 3 rows affected.
# +-----------+-----------------+
# | vendor_id |   vendor_name   |
# +-----------+-----------------+
# |     2     |     VeriFone    |
# |     6     |     Unknown     |
# |     1     | Creative Mobile |
# +-----------+-----------------+

# %%
# %%bash
# psql postgresql://root:root@localhost:5432/ny_taxi <<'SQL'
# CREATE OR REPLACE VIEW curated.vw_trip_denorm AS
# SELECT
#     t.trip_id,
#     DATE(t.pickup_datetime) AS pickup_date,
#     EXTRACT(HOUR FROM t.pickup_datetime) AS pickup_hour,
#     t.trip_distance,
#     t.total_amount,
#     v.vendor_name,
#     z.zone_name  AS pickup_zone,
#     z.borough   AS pickup_borough
# FROM curated.trip t
# LEFT JOIN curated.vendor v
#        ON t.vendor_id = v.vendor_id
# LEFT JOIN curated.zone z
#        ON t.pulocation_id = z.location_id;
# Out:
# bash: line 16: warning: here-document at line 1 delimited by end-of-file (wanted `SQL')
# CREATE VIEW

# %%
# %%sql
# SELECT * FROM curated.vw_trip_denorm
# LIMIT 10
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 10 rows affected.
# +---------+-------------+-------------+---------------+--------------+-----------------+------------------------------+----------------+
# | trip_id | pickup_date | pickup_hour | trip_distance | total_amount |   vendor_name   |         pickup_zone          | pickup_borough |
# +---------+-------------+-------------+---------------+--------------+-----------------+------------------------------+----------------+
# | 1724582 |  2024-01-01 |     0.0     |      1.72     |     22.7     |     VeriFone    | Penn Station/Madison Sq West |   Manhattan    |
# | 1724583 |  2024-01-01 |     0.0     |      1.8      |    18.75     | Creative Mobile |       Lenox Hill East        |   Manhattan    |
# | 1724584 |  2024-01-01 |     0.0     |      4.7      |     31.3     | Creative Mobile |    Upper East Side North     |   Manhattan    |
# | 1724585 |  2024-01-01 |     0.0     |      1.4      |     17.0     | Creative Mobile |         East Village         |   Manhattan    |
# | 1724586 |  2024-01-01 |     0.0     |      0.8      |     16.1     | Creative Mobile |             SoHo             |   Manhattan    |
# | 1724587 |  2024-01-01 |     0.0     |      4.7      |     41.5     | Creative Mobile |       Lower East Side        |   Manhattan    |
# | 1724588 |  2024-01-01 |     0.0     |     10.82     |    64.95     |     VeriFone    |      LaGuardia Airport       |     Queens     |
# | 1724589 |  2024-01-01 |     0.0     |      3.0      |     30.4     | Creative Mobile |  West Chelsea/Hudson Yards   |   Manhattan    |
# | 1724590 |  2024-01-01 |     0.0     |      5.44     |     36.0     |     VeriFone    |        Midtown Center        |   Manhattan    |
# | 1724591 |  2024-01-01 |     0.0     |      0.04     |     8.0      |     VeriFone    |   Greenwich Village North    |   Manhattan    |
# +---------+-------------+-------------+---------------+--------------+-----------------+------------------------------+----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT count(*) FROM curated.vw_trip_denorm
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 1 rows affected.
# +---------+
# |  count  |
# +---------+
# | 2964624 |
# +---------+

# %%
# %%sql
# CREATE MATERIALIZED VIEW curated.mv_daily_zone AS
# SELECT
#     DATE(pickup_datetime) AS pickup_date,
#     pulocation_id,
#     COUNT(*)              AS trips,
#     SUM(total_amount)     AS revenue
# FROM curated.trip
# GROUP BY
#     DATE(pickup_datetime),
#     pulocation_id;
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 6966 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * FROM curated.mv_daily_zone
# LIMIT 10
# Out:
# Running query in 'postgresql://root:***@localhost:5432/ny_taxi'
# 10 rows affected.
# +-------------+---------------+-------+----------+
# | pickup_date | pulocation_id | trips | revenue  |
# +-------------+---------------+-------+----------+
# |  2024-01-21 |       41      |  218  | 4247.97  |
# |  2024-01-10 |      210      |   6   |  279.0   |
# |  2024-01-31 |       14      |   10  |  524.95  |
# |  2024-01-29 |       35      |   17  |  626.48  |
# |  2024-01-20 |       79      |  4473 | 94645.55 |
# |  2024-01-09 |       28      |   19  | 1050.00  |
# |  2024-01-08 |      137      |  914  | 19275.47 |
# |  2024-01-24 |      182      |   9   |  331.94  |
# |  2024-01-15 |       50      |  499  | 10518.59 |
# |  2024-01-04 |      117      |   12  |  560.35  |
# +-------------+---------------+-------+----------+
# Truncated to displaylimit of 10.
